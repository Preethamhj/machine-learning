# %%
import pandas as pd 
file_path="student_exam_data_new.xlsx"
df = pd.read_excel(file_path)

print(df.head())
# Out:
#    StudyHours      Marks  Attendance  Pass/Fail
# 0    4.370861  81.889703          84        0.0
# 1    9.556429  72.165782          64        1.0
# 2    7.587945  58.571657          98        0.0
# 3    6.387926  88.827701          89        1.0
# 4    2.404168  81.083870          92        0.0

# %%
print(df.shape)
print(df.columns)

print(df.describe())
print(df.isnull().sum())
# Out:
# (6607, 4)
# Index(['StudyHours', 'Marks', 'Attendance', 'Pass/Fail'], dtype='object')
#        StudyHours       Marks   Attendance   Pass/Fail
# count  500.000000  500.000000  6607.000000  500.000000
# mean     5.487055   68.917084    79.977448    0.368000
# std      2.688196   17.129607    11.547475    0.482744
# min      1.045554   40.277921    60.000000    0.000000
# 25%      3.171517   53.745955    70.000000    0.000000
# 50%      5.618474   68.309294    80.000000    0.000000
# 75%      7.805124   83.580209    90.000000    1.000000
# max      9.936683   99.983060   100.000000    1.000000
# StudyHours    6107
# Marks         6107
# Attendance       0
# Pass/Fail     6107
# dtype: int64

# %%
x=  df[["Attendance","StudyHours","Marks"]]
y=   df[["Pass/Fail"]]

# %%
import matplotlib.pyplot as plt 
import seaborn as sns

sns.pairplot(df, hue="Pass/Fail")
plt.show()

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression

pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy='mean')),  # fill NaN with mean
    ('scaler', StandardScaler()),
    ('clf', LogisticRegression(solver='liblinear', random_state=42))
])
pipeline.fit(x_train, y_train)
y_pred = pipeline.predict(x_test)
y_proba = pipeline.predict_proba(x_test)[:,1]
# Out:
# c:\Users\ASUS\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\utils\validation.py:1111: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
